# %% [markdown]
# # DECISION TREE

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df=pd.read_csv('DecisionTreeDataset -Num.csv')
df.head()
# Out:
#    CGPA  Communication  Apptitude  Programming Skill  Job Offered
# 0     1              1          1                  1            1
# 1     2              1          1                  1            1
# 2     0              0          0                  1            0
# 3     0              1          0                  0            0
# 4     2              1          1                  0            1

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=4)

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier(criterion='entropy',max_depth=4)
dtree.fit(x_train,y_train)
dtree.get_depth()
# Out:
# 3

# %%
from sklearn import tree
tr = tree.export_text(dtree)
print(tr)
# Out:
# |--- feature_2 <= 0.50
# |   |--- class: 0
# |--- feature_2 >  0.50
# |   |--- feature_1 <= 0.50
# |   |   |--- feature_0 <= 1.50
# |   |   |   |--- class: 0
# |   |   |--- feature_0 >  1.50
# |   |   |   |--- class: 1
# |   |--- feature_1 >  0.50
# |   |   |--- class: 1

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier,export_text,plot_tree

plt.figure(figsize=(25,20))
plot_tree(dtree,filled=True,feature_names=['CGPA','APPTITUDE','COMMUNICATION','PROGRAMMING_SKILL'],class_names=['NO','YES'])
# Out:
# [Text(558.0, 951.3000000000001, 'COMMUNICATION <= 0.5\nentropy = 1.0\nsamples = 12\nvalue = [6, 6]\nclass = NO'),
#  Text(279.0, 679.5, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = NO'),
#  Text(837.0, 679.5, 'APPTITUDE <= 0.5\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]\nclass = YES'),
#  Text(558.0, 407.70000000000005, 'CGPA <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = NO'),
#  Text(279.0, 135.89999999999998, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = NO'),
#  Text(837.0, 135.89999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = YES'),
#  Text(1116.0, 407.70000000000005, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = YES')]

# %%
from sklearn.preprocessing

# %%
y_pred=dtree.predict(x_test)

# %%
y
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     1
# 5     1
# 6     0
# 7     0
# 8     1
# 9     1
# 10    0
# 11    0
# 12    1
# 13    0
# 14    0
# 15    0
# 16    0
# 17    1
# Name: Job Offered, dtype: int64

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[4 0]
#  [0 2]]

# %%
TN = cm[0][0]
FP = cm[0][1]
FN = cm[1][0]
TP = cm[1][1]
print(TP, FN, TN, FP)
accuracy = (TP + TN) / (TP + FP + FN + TN)
accuracy
# Out:
# 2 0 4 0
# 1.0

# %%
df=pd.read_csv('diabetes.csv')
df.head
# Out:
# <bound method NDFrame.head of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
x = df.iloc[:, 0:8]
y = df.iloc[:, 8]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)
dtree_entropy = DecisionTreeClassifier(criterion='entropy',max_depth=23)

model = dtree_entropy.fit(x_train, y_train)
dtree_entropy.get_depth()
# Out:
# 17

# %%
from sklearn import tree
tr = tree.export_text(dtree)
print(tr)
# Out:
# |--- feature_2 <= 0.50
# |   |--- class: 0
# |--- feature_2 >  0.50
# |   |--- feature_1 <= 0.50
# |   |   |--- feature_0 <= 1.50
# |   |   |   |--- class: 0
# |   |   |--- feature_0 >  1.50
# |   |   |   |--- class: 1
# |   |--- feature_1 >  0.50
# |   |   |--- class: 1

# %%
prediction = dtree_entropy.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, prediction)
cm
# Out:
# array([[120,  35],
#        [ 32,  44]], dtype=int64)

# %%
TN = cm[0][0]
FP = cm[0][1]
FN = cm[1][0]
TP = cm[1][1]
print(TP, FN, TN, FP)

accuracy = (TP + TN) / (TP + FP + FN + TN)
accuracy
# Out:
# 44 32 120 35
# 0.70995670995671
